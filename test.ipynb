# %%
from strategy import MyStrategy
import json

with open('config.json', 'r') as f:
    config = json.load(f)

st = MyStrategy(api_key=config['API_KEY'], api_secret=config['API_SECRET'], 
                symbol='EOSUSDT', 
                openTH=0.01, closeTH=0.002, 
                qtyWeight=2, THWeight=2,
                limit=99, interval='1')

print(st.trader)
st.startTrade()
# Out:
#  - Symbol: EOSUSDT
#  - qty_step: 0.1
#  - tick_size: 0.001
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23984/610239293.py in <module>
#      12
#      13 print(st.trader)
# ---> 14 st.startTrade()
#
# d:\source\git\bybit\strategy.py in startTrade(self)
#     142
#     143     def startTrade(self) -> int:
# --> 144         if self.trader.hasPosition():
#     145             return -1
#     146
#
# d:\source\git\bybit\derivativesTrader.py in hasPosition(self)
#      45
#      46     def hasPosition(self) -> bool:
# ---> 47         for position in self.getPositions().result:
#      48             if position['size'] > 0:
#      49                 return True
#
# d:\source\git\bybit\derivativesTrader.py in getPositions(self)
#      42
#      43     def getPositions(self) -> Responses.Positions:
# ---> 44         return Responses.Positions(self.client.LinearPositions.LinearPositions_myPosition(symbol=self.symbol).result())
#      45
#      46     def hasPosition(self) -> bool:
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado\client.py in __call__(self, **op_kwargs)
#     245
#     246         request_params = construct_request(
# --> 247             self.operation, request_options, **op_kwargs)
#     248
#     249         http_client = self.operation.swagger_spec.http_client
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado\client.py in construct_request(operation, request_options, **op_kwargs)
#     283             request[request_option] = request_options[request_option]
#     284
# --> 285     construct_params(operation, request, op_kwargs)
#     286
#     287     return request
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado\client.py in construct_params(operation, request, op_kwargs)
#     306                 "{0} does not have parameter {1}"
#     307                 .format(operation.operation_id, param_name))
# --> 308         marshal_param(param, param_value, request)
#     309
#     310     # Check required params and non-required params with a 'default' value
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado_core\param.py in marshal_param(param, value, request)
#     131
#     132     if swagger_spec.config['validate_requests']:
# --> 133         validate_schema_object(swagger_spec, param_spec, value)
#     134
#     135     param_type = param_spec.get('type')
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado_core\validate.py in validate_schema_object(swagger_spec, schema_object_spec, value)
#      66
#      67     if obj_type in SWAGGER_PRIMITIVES:
# ---> 68         validate_primitive(swagger_spec, schema_object_spec, value)
#      69
#      70     elif obj_type == 'array':
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado_core\validate.py in scrubbed(*args, **kwargs)
#      41                 e.message = '*** ' + e.message[len(str(e.instance)):]
#      42                 e.instance = '***'
# ---> 43             reraise(*sys.exc_info())
#      44
#      45     return scrubbed  # type: ignore  # ignoring type to avoiding typing.cast call
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado_core\validate.py in scrubbed(*args, **kwargs)
#      33         # type: (typing.Any, typing.Any) -> typing.Any
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except jsonschema.ValidationError as e:
#      37             if (
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\bravado_core\validate.py in validate_primitive(swagger_spec, primitive_spec, value)
#      99         format_checker=swagger_spec.format_checker,
#     100         resolver=swagger_spec.resolver,
# --> 101     ).validate(value)
#     102
#     103
#
# D:\ProgramFiles\anaconda3\envs\torch\lib\site-packages\jsonschema\validators.py in validate(self, *args, **kwargs)
#     247         def validate(self, *args, **kwargs):
#     248             for error in self.iter_errors(*args, **kwargs):
# --> 249                 raise error
#     250
#     251         def is_type(self, instance, type):
#
# ValidationError: <coinsymbol.Symbol object at 0x00000209E45E5AC8> is not of type 'string'
#
# Failed validating 'type' in schema:
#     {'in': 'query', 'name': 'symbol', 'required': False, 'type': 'string'}
#
# On instance:
#     <coinsymbol.Symbol object at 0x00000209E45E5AC8>
